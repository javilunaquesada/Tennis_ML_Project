# %% [markdown]
# ### Load Data

# %%
import pandas as pd
import glob
import os

DATA_PATH = "../data/raw/"

# Load match files (2018–2024)
match_files = sorted(glob.glob(os.path.join(DATA_PATH, "atp_matches_20*.csv")))
print("Files loaded:")
for f in match_files:
    print(f)

dfs = []
for file in match_files:
    df = pd.read_csv(file)

    year = int(os.path.basename(file).split("_")[-1].split(".")[0]) # os.path.basename gets the file name from the path
    df["year"] = year                                               # split("_") returns a list ['atp', 'matches', '2018.csv'], and we take the last element [-1]
                                                                    # split(".") returns a list ['2018', 'csv'], and we take the first element [0], then convert it to int

    dfs.append(df)

matches = pd.concat(dfs, ignore_index=True)

print("\nTotal matches:", matches.shape[0])
print("Total columns:", matches.shape[1])
print("\nColumns:", matches.columns.tolist())

matches.head()
# Out:
# Files loaded:
# ../data/raw\atp_matches_2018.csv
# ../data/raw\atp_matches_2019.csv
# ../data/raw\atp_matches_2020.csv
# ../data/raw\atp_matches_2021.csv
# ../data/raw\atp_matches_2022.csv
# ../data/raw\atp_matches_2023.csv
# ../data/raw\atp_matches_2024.csv
#
# Total matches: 18877
# Total columns: 50
#
# Columns: ['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level', 'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry', 'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age', 'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced', 'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points', 'year']
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2018-M020     Brisbane    Hard         32             A      20180101
# 1  2018-M020     Brisbane    Hard         32             A      20180101
# 2  2018-M020     Brisbane    Hard         32             A      20180101
# 3  2018-M020     Brisbane    Hard         32             A      20180101
# 4  2018-M020     Brisbane    Hard         32             A      20180101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        271     105992          NaN          NaN  ...     33.0     19.0
# 1        272     111577          NaN          NaN  ...     25.0      7.0
# 2        273     104797          NaN          NaN  ...     37.0     29.0
# 3        275     200282          NaN           WC  ...     33.0     17.0
# 4        276     111581          NaN            Q  ...     28.0      5.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank  winner_rank_points loser_rank  \
# 0     14.0       1.0        4.0         47.0              1010.0       52.0
# 1      9.0       7.0       11.0         54.0               890.0       94.0
# 2     15.0      10.0       16.0         63.0               809.0       30.0
# 3     11.0       4.0        6.0        208.0               245.0       44.0
# 4      9.0       0.0        2.0        175.0               299.0       68.0
#
#   loser_rank_points  year
# 0             909.0  2018
# 1             593.0  2018
# 2            1391.0  2018
# 3            1055.0  2018
# 4             755.0  2018
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Quick Inspection

# %%
matches.info()

matches.describe(include="all").T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18877 entries, 0 to 18876
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          18877 non-null  object
#  1   tourney_name        18877 non-null  object
#  2   surface             18824 non-null  object
#  3   draw_size           18877 non-null  int64
#  4   tourney_level       18877 non-null  object
#  5   tourney_date        18877 non-null  int64
#  6   match_num           18877 non-null  int64
#  7   winner_id           18877 non-null  int64
#  8   winner_seed         7773 non-null   float64
#  9   winner_entry        2885 non-null   object
#  10  winner_name         18877 non-null  object
#  11  winner_hand         18877 non-null  object
#  12  winner_ht           18798 non-null  float64
#  13  winner_ioc          18877 non-null  object
#  14  winner_age          18874 non-null  float64
#  15  loser_id            18877 non-null  int64
#  16  loser_seed          4670 non-null   float64
#  17  loser_entry         4343 non-null   object
#  18  loser_name          18877 non-null  object
#  19  loser_hand          18876 non-null  object
#  20  loser_ht            18650 non-null  float64
#  21  loser_ioc           18877 non-null  object
#  22  loser_age           18874 non-null  float64
#  23  score               18877 non-null  object
#  24  best_of             18877 non-null  int64
#  25  round               18877 non-null  object
#  26  minutes             17844 non-null  float64
#  27  w_ace               18183 non-null  float64
#  28  w_df                18183 non-null  float64
#  29  w_svpt              18183 non-null  float64
#  30  w_1stIn             18183 non-null  float64
#  31  w_1stWon            18183 non-null  float64
#  32  w_2ndWon            18183 non-null  float64
#  33  w_SvGms             18183 non-null  float64
#  34  w_bpSaved           18183 non-null  float64
#  35  w_bpFaced           18183 non-null  float64
#  36  l_ace               18183 non-null  float64
#  37  l_df                18183 non-null  float64
#  38  l_svpt              18183 non-null  float64
#  39  l_1stIn             18183 non-null  float64
#  40  l_1stWon            18183 non-null  float64
#  41  l_2ndWon            18183 non-null  float64
#  42  l_SvGms             18183 non-null  float64
#  43  l_bpSaved           18183 non-null  float64
#  44  l_bpFaced           18183 non-null  float64
#  45  winner_rank         18798 non-null  float64
#  46  winner_rank_points  18798 non-null  float64
#  47  loser_rank          18655 non-null  float64
#  48  loser_rank_points   18655 non-null  float64
#  49  year                18877 non-null  int64
# dtypes: float64(29), int64(7), object(14)
# memory usage: 7.2+ MB
#                       count unique               top   freq             mean  \
# tourney_id            18877    894          2019-520    127              NaN
# tourney_name          18877    548   Australian Open    889              NaN
# surface               18824      3              Hard  11206              NaN
# draw_size           18877.0    NaN               NaN    NaN        60.761456
# tourney_level         18877      6                 A  10179              NaN
# tourney_date        18877.0    NaN               NaN    NaN  20211778.128357
# match_num           18877.0    NaN               NaN    NaN        254.80712
# winner_id           18877.0    NaN               NaN    NaN    131474.676008
# winner_seed          7773.0    NaN               NaN    NaN         7.773189
# winner_entry           2885     10                 Q   1501              NaN
# winner_name           18877    660   Daniil Medvedev    350              NaN
# winner_hand           18877      3                 R  16392              NaN
# winner_ht           18798.0    NaN               NaN    NaN        187.66406
# winner_ioc            18877     88               USA   1987              NaN
# winner_age          18874.0    NaN               NaN    NaN        26.950005
# loser_id            18877.0    NaN               NaN    NaN    130882.999682
# loser_seed           4670.0    NaN               NaN    NaN         9.102998
# loser_entry            4343     10                 Q   2203              NaN
# loser_name            18877    877  Adrian Mannarino    180              NaN
# loser_hand            18876      3                 R  16117              NaN
# loser_ht            18650.0    NaN               NaN    NaN       186.692708
# loser_ioc             18877     93               USA   2002              NaN
# loser_age           18874.0    NaN               NaN    NaN        27.204726
# score                 18877   4631           6-4 6-4    671              NaN
# best_of             18877.0    NaN               NaN    NaN         3.374106
# round                 18877      9               R32   5756              NaN
# minutes             17844.0    NaN               NaN    NaN       114.538949
# w_ace               18183.0    NaN               NaN    NaN         7.185888
# w_df                18183.0    NaN               NaN    NaN         2.621295
# w_svpt              18183.0    NaN               NaN    NaN        79.331353
# w_1stIn             18183.0    NaN               NaN    NaN        50.009569
# w_1stWon            18183.0    NaN               NaN    NaN         37.92152
# w_2ndWon            18183.0    NaN               NaN    NaN        16.219601
# w_SvGms             18183.0    NaN               NaN    NaN         12.76632
# w_bpSaved           18183.0    NaN               NaN    NaN         3.451081
# w_bpFaced           18183.0    NaN               NaN    NaN         4.989221
# l_ace               18183.0    NaN               NaN    NaN         5.447836
# l_df                18183.0    NaN               NaN    NaN         3.249079
# l_svpt              18183.0    NaN               NaN    NaN        82.378265
# l_1stIn             18183.0    NaN               NaN    NaN        50.672771
# l_1stWon            18183.0    NaN               NaN    NaN        34.066656
# l_2ndWon            18183.0    NaN               NaN    NaN        14.718913
# l_SvGms             18183.0    NaN               NaN    NaN        12.527581
# l_bpSaved           18183.0    NaN               NaN    NaN         4.794423
# l_bpFaced           18183.0    NaN               NaN    NaN         8.507782
# winner_rank         18798.0    NaN               NaN    NaN        73.880147
# winner_rank_points  18798.0    NaN               NaN    NaN      1851.890254
# loser_rank          18655.0    NaN               NaN    NaN       105.873117
# loser_rank_points   18655.0    NaN               NaN    NaN      1179.155186
# year                18877.0    NaN               NaN    NaN      2021.124596
#
#                              std         min         25%         50%  \
# tourney_id                   NaN         NaN         NaN         NaN
# tourney_name                 NaN         NaN         NaN         NaN
# surface                      NaN         NaN         NaN         NaN
# draw_size              43.492081         2.0        32.0        32.0
# tourney_level                NaN         NaN         NaN         NaN
# tourney_date        20772.839969  20180101.0  20190722.0  20210920.0
# match_num             141.320215         1.0       220.0       277.0
# winner_id           38336.092844    100644.0    105526.0    109739.0
# winner_seed             7.191888         1.0         3.0         6.0
# winner_entry                 NaN         NaN         NaN         NaN
# winner_name                  NaN         NaN         NaN         NaN
# winner_hand                  NaN         NaN         NaN         NaN
# winner_ht                7.25474         3.0       183.0       188.0
# winner_ioc                   NaN         NaN         NaN         NaN
# winner_age              4.609734        14.9        23.4        26.5
# loser_id            38147.583643    100644.0    105550.0    106426.0
# loser_seed              7.669153         1.0         4.0         7.0
# loser_entry                  NaN         NaN         NaN         NaN
# loser_name                   NaN         NaN         NaN         NaN
# loser_hand                   NaN         NaN         NaN         NaN
# loser_ht                7.186454        15.0       183.0       185.0
# loser_ioc                    NaN         NaN         NaN         NaN
# loser_age               4.607236        14.5        23.7        26.9
# score                        NaN         NaN         NaN         NaN
# best_of                 0.779929         3.0         3.0         3.0
# round                        NaN         NaN         NaN         NaN
# minutes                42.741781         0.0        83.0       107.0
# w_ace                   5.638047         0.0         3.0         6.0
# w_df                    2.316791         0.0         1.0         2.0
# w_svpt                 29.209802         4.0        58.0        74.0
# w_1stIn                19.150574         2.0        36.0        47.0
# w_1stWon               13.710521         1.0        28.0        36.0
# w_2ndWon                6.713204         0.0        11.0        15.0
# w_SvGms                  4.24601         0.0        10.0        12.0
# w_bpSaved               3.060047         0.0         1.0         3.0
# w_bpFaced               4.004685         0.0         2.0         4.0
# l_ace                   5.114293         0.0         2.0         4.0
# l_df                     2.52854         0.0         1.0         3.0
# l_svpt                  29.07633         3.0        61.0        77.0
# l_1stIn                19.276929         2.0        37.0        47.0
# l_1stWon               14.457915         0.0        24.0        32.0
# l_2ndWon                6.928165         0.0        10.0        14.0
# l_SvGms                 4.232659         0.0         9.0        12.0
# l_bpSaved               3.300196         0.0         2.0         4.0
# l_bpFaced               4.179747         0.0         6.0         8.0
# winner_rank            120.97202         1.0        18.0        46.0
# winner_rank_points   2058.795689         1.0       704.0      1066.0
# loser_rank            162.893977         1.0        35.0        66.0
# loser_rank_points    1252.418207         1.0       559.0       849.0
# year                    2.071652      2018.0      2019.0      2021.0
#
#                            75%         max
# tourney_id                 NaN         NaN
# tourney_name               NaN         NaN
# surface                    NaN         NaN
# draw_size                128.0       128.0
# tourney_level              NaN         NaN
# tourney_date        20230522.0  20241218.0
# match_num                291.0      1701.0
# winner_id             134770.0    212721.0
# winner_seed               10.0        33.0
# winner_entry               NaN         NaN
# winner_name                NaN         NaN
# winner_hand                NaN         NaN
# winner_ht                193.0       211.0
# winner_ioc                 NaN         NaN
# winner_age                30.1        44.6
# loser_id              133835.0    212970.0
# loser_seed                12.0        33.0
# loser_entry                NaN         NaN
# loser_name                 NaN         NaN
# loser_hand                 NaN         NaN
# loser_ht                 191.0       211.0
# loser_ioc                  NaN         NaN
# loser_age                 30.3        43.9
# score                      NaN         NaN
# best_of                    3.0         5.0
# round                      NaN         NaN
# minutes                  139.0       396.0
# w_ace                     10.0        64.0
# w_df                       4.0        26.0
# w_svpt                    95.0       278.0
# w_1stIn                   60.0       198.0
# w_1stWon                  45.0       166.0
# w_2ndWon                  20.0        56.0
# w_SvGms                   15.0        49.0
# w_bpSaved                  5.0        23.0
# w_bpFaced                  7.0        30.0
# l_ace                      7.0        67.0
# l_df                       4.0        26.0
# l_svpt                    99.0       291.0
# l_1stIn                   61.0       218.0
# l_1stWon                  42.0       171.0
# l_2ndWon                  19.0        52.0
# l_SvGms                   15.0        50.0
# l_bpSaved                  7.0        27.0
# l_bpFaced                 11.0        38.0
# winner_rank               85.0      1821.0
# winner_rank_points      2079.5     12415.0
# loser_rank               109.0      2146.0
# loser_rank_points       1307.0     12355.0
# year                    2023.0      2024.0

# %%
selected_cols = [
    "year",
    "tourney_date",
    "surface",
    "tourney_level",
    
    "winner_id",
    "winner_name",
    "winner_rank",
    "winner_age",
    "winner_ht",
    
    "loser_id",
    "loser_name",
    "loser_rank",
    "loser_age",
    "loser_ht",
    
    "w_ace", "w_df", "w_bpSaved", "w_bpFaced",
    "l_ace", "l_df", "l_bpSaved", "l_bpFaced"
]

matches = matches[selected_cols]
print(matches.shape)
matches.head(2)
# Out:
# (18877, 22)
#    year  tourney_date surface tourney_level  winner_id      winner_name  \
# 0  2018      20180101    Hard             A     105992    Ryan Harrison
# 1  2018      20180101    Hard             A     111577  Jared Donaldson
#
#    winner_rank  winner_age  winner_ht  loser_id  ... loser_age  loser_ht  \
# 0         47.0        25.6      185.0    104919  ...      30.6     188.0
# 1         54.0        21.2      188.0    111442  ...      23.7     183.0
#
#    w_ace  w_df  w_bpSaved  w_bpFaced  l_ace  l_df  l_bpSaved  l_bpFaced
# 0    9.0   2.0        8.0        9.0   10.0   3.0        1.0        4.0
# 1    5.0   3.0        4.0        5.0    3.0   5.0        7.0       11.0
#
# [2 rows x 22 columns]

# %%
missing_ratio = matches.isna().mean().sort_values(ascending=False)
missing_ratio[missing_ratio > 0]
# Out:
# l_bpFaced      0.036764
# l_bpSaved      0.036764
# l_df           0.036764
# l_ace          0.036764
# w_bpFaced      0.036764
# w_bpSaved      0.036764
# w_df           0.036764
# w_ace          0.036764
# loser_ht       0.012025
# loser_rank     0.011760
# winner_ht      0.004185
# winner_rank    0.004185
# surface        0.002808
# loser_age      0.000159
# winner_age     0.000159
# dtype: float64

# %% [markdown]
# ### Save Matches In New Dir

# %%
os.makedirs("../data/processed", exist_ok=True)
matches.to_csv("../data/processed/matches_base.csv", index=False)
